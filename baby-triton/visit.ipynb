# %% [markdown]
# 这个notebook主要是对python 重载的一些想法和验证 应该不需要再多写验证即可

# %%
class NodeVisitor():

    def visit(self, node):
        """Visit a node."""
        method = 'visit_' + node.__class__.__name__
        return self.generic_visit(node)

    def generic_visit(self, node):
        """Called if no explicit visitor function exists for a node."""
        print("father gen")
        if node > 0:
            node-=1 
            self.visit(node)

class CodeGenerator(NodeVisitor):
    def __init__(self, fn_ast, target):
        self.fn_ast = fn_ast
        self.target = target
    
    def code_gen(self):
        self.visit(self.fn_ast)

    def visit(self, node):
        print("Visit " + node.__class__.__name__)
        return super().visit(node)

    def generic_visit(self, node):
        print("son gen")
        return super().generic_visit(node)
    
code = CodeGenerator(0, 0)
code.code_gen()
# Out:
# Visit int
# son gen
# father gen

# %%
import ast
import IPython
import inspect

IPython.display.Code(inspect.getsource(ast.NodeVisitor.visit), language="python")

#其中对于method = 'visit_' + node.__class__.__name__
#        visitor = getattr(self, method, self.generic_visit)
#等价于调用函数名为 visit_{node.__class__.__name__}的函数
# Out:
#     def visit(self, node):
#         """Visit a node."""
#         method = 'visit_' + node.__class__.__name__
#         visitor = getattr(self, method, self.generic_visit)
#         return visitor(node)
